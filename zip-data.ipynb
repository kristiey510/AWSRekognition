# %%
## zip files to download and transfer to S3 buckets

# !zip -r -X tranformedData.zip transformed_imgs #zip file to store tranformed images
# !zip -r -X originalData.zip original_imgs #zip file to store original images
# Out:
#   adding: transformed_imgs/ (stored 0%)
#   adding: transformed_imgs/food2-contrast:1.5.jpg (deflated 1%)
#   adding: transformed_imgs/food6-contrast:0.9.jpg (deflated 2%)
#   adding: transformed_imgs/crosswalk2-contrast:0.9.jpg (deflated 0%)
#   adding: transformed_imgs/crosswalk9-contrast:0.7.jpg (deflated 0%)
#   adding: transformed_imgs/crosswalk10-sharp:1.8.jpg (deflated 0%)
#   adding: transformed_imgs/food7-bright:1.3.jpg (deflated 0%)
#   adding: transformed_imgs/food5-sharp:1.6.jpg (deflated 0%)
#   adding: transformed_imgs/food8-sharp:0.8.jpg (deflated 0%)
#   adding: transformed_imgs/crosswalk6-sharp:0.4.jpg (deflated 4%)
#   adding: transformed_imgs/crosswalk7-sharp:2.0.jpg (deflated 0%)
#   adding: transformed_imgs/food4-bright:0.9.jpg (deflated 0%)
#   adding: transformed_imgs/crosswalk8-contrast:0.7.jpg (deflated 0%)
#   adding: transformed_imgs/crosswalk4-bright:1.4.jpg (deflated 0%)
#   adding: transformed_imgs/crosswalk1-contrast:0.8.jpg (deflated 5%)
# ...
